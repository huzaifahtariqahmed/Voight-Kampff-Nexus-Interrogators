# %%
# !pip install gdown

# %%
import os

# %%
target_dir = "/content/st2data"
os.makedirs(target_dir, exist_ok=True)
# !gdown "https://drive.google.com/uc?id=1u5C4o_fmjL5nQ_RtgLDShuG97Ix6_KGK" -O "/content/st2data/train.jsonl"
# !gdown "https://drive.google.com/uc?id=1rNQTkhkVG9nzcT97Nk_WyJd80ZaacT0-" -O "/content/st2data/val.jsonl"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1u5C4o_fmjL5nQ_RtgLDShuG97Ix6_KGK
# From (redirected): https://drive.google.com/uc?id=1u5C4o_fmjL5nQ_RtgLDShuG97Ix6_KGK&confirm=t&uuid=67235ad3-6eeb-4fbe-84fb-be988321afa8
# To: /content/st2data/train.jsonl
# 100% 662M/662M [00:08<00:00, 81.1MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1rNQTkhkVG9nzcT97Nk_WyJd80ZaacT0-
# From (redirected): https://drive.google.com/uc?id=1rNQTkhkVG9nzcT97Nk_WyJd80ZaacT0-&confirm=t&uuid=74da50ff-6916-4c81-b7e2-dd918237ac42
# To: /content/st2data/val.jsonl
# 100% 140M/140M [00:02<00:00, 58.7MB/s]
